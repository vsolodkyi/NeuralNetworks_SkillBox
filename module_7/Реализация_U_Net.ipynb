# %% [markdown]
# <a href="https://colab.research.google.com/github/vsolodkyi/NeuralNetworks_SkillBox/blob/main/module_7/%D0%A0%D0%B5%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D1%8F_U_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Реализация U-Net
# В этом уроке мы создадим еще более качественную FCN модель на основе архитектуры UNet. Кроме использовавшихся ранее слоёв, здесь также будут участвовать Skipped Connections (проброшенные связи).

# %% [markdown]
# ### Загрузка необходимых библиотек
# Здесь мы загружаем различне библиотеки, включая TensoFlow.

# %%
import numpy as np

import tensorflow as tf
# tf.enable_eager_execution()
print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.8.2

# %% [markdown]
# ### Создание UNet модели
# Так как UNet имееет разветвления, мы не сможем создать её с помощью `tf.keras.Sequential`. Остаётся либо создать свой собственный класс, либо использовать функциональный API. Так как граф у нас будет статический (без каких-то условных ветвлений), и нам потом желательно визуализировать полученный граф, чтобы проверить, что мы всё соединили правильно, мы будем использовать именно функциональный API.
#
# В архитектуре UNet для понижения размерности используется MaxPooling, а для повышения -- Conv2DTranspose (Транспонированная свёртка, Upconv). Кроме того, присутствуют проброшенные связи (skipped connections): некоторые тензоры из Энкодера конкатенируются по канальному измерению (axis=3) с тензорами из Декодера. В остальном эта модель очень похожа на обычныйю Encoder-Decoder нейросеть из предыдущего практического урока.
#
# В отличие от классической UNet архитектуры, мы во всех слоях  будем использовать `padding='same'`, чтобы избавиться от необходимости делать crop при конкатинации тензоров из разных участков сети.

# %%
def build_model():
    x = tf.keras.layers.Input((256, 256, 3))
    
    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    out1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.MaxPool2D((2, 2))(out1)

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out2 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.MaxPool2D((2, 2))(out2)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out3 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.MaxPool2D((2, 2))(out3)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out4 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.MaxPool2D((2, 2))(out4)

    out = tf.keras.layers.Conv2D(1024, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(1024, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(512, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out4, out], axis=3)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out3, out], axis=3)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out2, out], axis=3)

    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.concat([out1, out], axis=3)

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation='sigmoid')(out)

    return tf.keras.Model(inputs=x, outputs=out)

model = build_model()

# %% [markdown]
# ### Визуализация графа модели UNet

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ### Задания

# %% [markdown]
# **[ЗАДАНИЕ 1]** Вопрос: почему при создании модели UNet нам потребовались дополнительные имена для переменных типа `out1`, `out2`, `out3`, `out4`, хотя раньше мы всегда могли обойтись одним именем `out`?
#
# **[Ответ:] Unet мережа в має в архітектурі входи з декількох джерел. При одному аут таку архітектуру побудувати неможливо**

# %% [markdown]
# **[ЗАДАНИЕ 2]** Создайте новую модель, аналогичную описанной выше, в котрой замените все Pooling слои на свёрточные слои со страйдом 2, а все Conv2DTranspose слои на комбинацию Nearest Unpooling и обычного свёрточного слоя.

# %%
def build_new_model():
    x = tf.keras.layers.Input((256, 256, 3))
    
    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    out1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)

    out = tf.keras.layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same', activation='relu')(out1)
    

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out2 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    
    out = tf.keras.layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same', activation='relu')(out2)
    #out = tf.keras.layers.MaxPool2D((2, 2))(out2)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out3 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same', activation='relu')(out3)
    #out = tf.keras.layers.MaxPool2D((2, 2))(out3)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out4 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(512, (3, 3), strides=(2, 2), padding='same', activation='relu')(out4)
    #out = tf.keras.layers.MaxPool2D((2, 2))(out4)

    out = tf.keras.layers.Conv2D(1024, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(1024, (3, 3), padding='same', activation='relu')(out)

    #out = tf.keras.layers.Conv2DTranspose(512, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.keras.layers.UpSampling2D((2,2))(out)
    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)

    out = tf.concat([out4, out], axis=3)

    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')(out)

    #out = tf.keras.layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.keras.layers.UpSampling2D((2,2))(out)
    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)

    out = tf.concat([out3, out], axis=3)

    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')(out)

    #out = tf.keras.layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.keras.layers.UpSampling2D((2,2))(out)
    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = tf.concat([out2, out], axis=3)

    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')(out)

    #out = tf.keras.layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same', activation='relu')(out)
    out = tf.keras.layers.UpSampling2D((2,2))(out)
    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.concat([out1, out], axis=3)

    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')(out)
    out = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation='sigmoid')(out)

    return tf.keras.Model(inputs=x, outputs=out)

new_model = build_new_model()

# %% [markdown]
# **[ЗАДАНИЕ 3]** Реализуйте пайплайн обучения для UNet модели: подготовка данных, лосс, обучение, тестирование. Используйте материалы из предыдущего практического урока. Обучите модель и сравните время обучения с временем обучения более простых версий FCN из предыдущих уроков.

# %%
import imageio
import matplotlib.pyplot as plt

# %%
img = imageio.imread('6.11_me_256.png')
img = img.astype(np.float32) / 255
_=plt.imshow(img)

# %%
gt = imageio.imread('6.11_me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[..., None]

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

# %%
# Ваш код здесь
# %%time
new_model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')
hist = new_model.fit(train_x,train_y, epochs=100, batch_size=1)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 2s 107ms/step - loss: 0.6865 - accuracy: 0.6525
# Epoch 2/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.6504 - accuracy: 0.8159
# Epoch 3/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.6691 - accuracy: 0.8615
# Epoch 4/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.6412 - accuracy: 0.8924
# Epoch 5/100
# 2/2 [==============================] - 0s 103ms/step - loss: 8.5922 - accuracy: 0.8156
# Epoch 6/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5830 - accuracy: 0.8817
# Epoch 7/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.6401 - accuracy: 0.7985
# Epoch 8/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.6379 - accuracy: 0.8034
# Epoch 9/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.6066 - accuracy: 0.8782
# Epoch 10/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5619 - accuracy: 0.9312
# Epoch 11/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5970 - accuracy: 0.8603
# Epoch 12/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.3826 - accuracy: 0.8960
# Epoch 13/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.4453 - accuracy: 0.8684
# Epoch 14/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.3644 - accuracy: 0.8854
# Epoch 15/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.2706 - accuracy: 0.8943
# Epoch 16/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.2570 - accuracy: 0.8819
# Epoch 17/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.2209 - accuracy: 0.9105
# Epoch 18/100
# 2/2 [==============================] - 0s 102ms/step - loss: 0.1959 - accuracy: 0.9021
# Epoch 19/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.1872 - accuracy: 0.9065
# Epoch 20/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.1838 - accuracy: 0.9439
# Epoch 21/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.1714 - accuracy: 0.9130
# Epoch 22/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.1563 - accuracy: 0.9479
# Epoch 23/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.1536 - accuracy: 0.9329
# Epoch 24/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.1290 - accuracy: 0.9459
# Epoch 25/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.1768 - accuracy: 0.9141
# Epoch 26/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.1827 - accuracy: 0.9162
# Epoch 27/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.1644 - accuracy: 0.9212
# Epoch 28/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.1414 - accuracy: 0.9403
# Epoch 29/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.1320 - accuracy: 0.9427
# Epoch 30/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.1294 - accuracy: 0.9577
# Epoch 31/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.1141 - accuracy: 0.9484
# Epoch 32/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.1011 - accuracy: 0.9579
# Epoch 33/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0914 - accuracy: 0.9586
# Epoch 34/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0790 - accuracy: 0.9701
# Epoch 35/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0756 - accuracy: 0.9715
# Epoch 36/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0703 - accuracy: 0.9729
# Epoch 37/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0642 - accuracy: 0.9742
# Epoch 38/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0532 - accuracy: 0.9801
# Epoch 39/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0484 - accuracy: 0.9818
# Epoch 40/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0474 - accuracy: 0.9824
# Epoch 41/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0475 - accuracy: 0.9815
# Epoch 42/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0439 - accuracy: 0.9832
# Epoch 43/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0388 - accuracy: 0.9855
# Epoch 44/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0338 - accuracy: 0.9863
# Epoch 45/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0269 - accuracy: 0.9889
# Epoch 46/100
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0315 - accuracy: 0.9876
# Epoch 47/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0280 - accuracy: 0.9885
# Epoch 48/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0255 - accuracy: 0.9898
# Epoch 49/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0228 - accuracy: 0.9902
# Epoch 50/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0203 - accuracy: 0.9915
# Epoch 51/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0174 - accuracy: 0.9926
# Epoch 52/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0158 - accuracy: 0.9934
# Epoch 53/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0154 - accuracy: 0.9936
# Epoch 54/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0164 - accuracy: 0.9931
# Epoch 55/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0140 - accuracy: 0.9942
# Epoch 56/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0123 - accuracy: 0.9951
# Epoch 57/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0167 - accuracy: 0.9933
# Epoch 58/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0118 - accuracy: 0.9950
# Epoch 59/100
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0108 - accuracy: 0.9954
# Epoch 60/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0116 - accuracy: 0.9952
# Epoch 61/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0104 - accuracy: 0.9958
# Epoch 62/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0091 - accuracy: 0.9963
# Epoch 63/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0087 - accuracy: 0.9966
# Epoch 64/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0084 - accuracy: 0.9968
# Epoch 65/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0086 - accuracy: 0.9966
# Epoch 66/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0079 - accuracy: 0.9968
# Epoch 67/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0074 - accuracy: 0.9970
# Epoch 68/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0074 - accuracy: 0.9969
# Epoch 69/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0074 - accuracy: 0.9970
# Epoch 70/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0086 - accuracy: 0.9965
# Epoch 71/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0080 - accuracy: 0.9967
# Epoch 72/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0086 - accuracy: 0.9965
# Epoch 73/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0078 - accuracy: 0.9967
# Epoch 74/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0077 - accuracy: 0.9968
# Epoch 75/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 76/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 77/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0085 - accuracy: 0.9964
# Epoch 78/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0067 - accuracy: 0.9974
# Epoch 79/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0066 - accuracy: 0.9973
# Epoch 80/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0065 - accuracy: 0.9974
# Epoch 81/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0067 - accuracy: 0.9973
# Epoch 82/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0086 - accuracy: 0.9964
# Epoch 83/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0067 - accuracy: 0.9973
# Epoch 84/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0059 - accuracy: 0.9977
# Epoch 85/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0056 - accuracy: 0.9978
# Epoch 86/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0062 - accuracy: 0.9973
# Epoch 87/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0067 - accuracy: 0.9973
# Epoch 88/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0169 - accuracy: 0.9936
# Epoch 89/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0089 - accuracy: 0.9962
# Epoch 90/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0092 - accuracy: 0.9961
# Epoch 91/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0085 - accuracy: 0.9964
# Epoch 92/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0081 - accuracy: 0.9967
# Epoch 93/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0073 - accuracy: 0.9970
# Epoch 94/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0073 - accuracy: 0.9970
# Epoch 95/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 96/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 97/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0065 - accuracy: 0.9974
# Epoch 98/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0060 - accuracy: 0.9976
# Epoch 99/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0056 - accuracy: 0.9977
# Epoch 100/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0058 - accuracy: 0.9975
# CPU times: user 22.2 s, sys: 256 ms, total: 22.4 s
# Wall time: 23.5 s

# %%
out = new_model.predict(img[None, ...])[0, ...]
_=plt.imshow(out[...,0])

# %%
for sample in train_x:
    out = new_model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('viridis')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
