# %% [markdown]
# <a href="https://colab.research.google.com/github/vsolodkyi/NeuralNetworks_SkillBox/blob/main/module_3/keras_training_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практика по обучению моделей
#
# В этом практическом задании мы закрепим на практике как обучать модели в tensorflow на синтетических данных. В задачах ниже необходимо получить точность выше 90%. Советуем не сдаваться на этом -- везде реально получить 100%. А в последнем задании можно получить бонусные баллы за модель с минимальным количеством параметров.

# %%
import tensorflow as tf
import numpy as np
#tf.enable_eager_execution()
print(tf.__version__)
# Out:
# 2.7.0

# %%
#@title
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap, Normalize
from sklearn.metrics import accuracy_score


# %matplotlib inline
np.random.seed(10)

colors = ['red', "blue"]
labels_cmap = ListedColormap(colors, 2)
colors = [(1, 0, 0), (1, 1, 1), (0, 0, 1)]  # R -> W -> B
main_cmap = LinearSegmentedColormap.from_list("main_scheme", colors, N=300)

def show_data(X, y):
    plt.figure(figsize=(5, 5))
    plt.scatter(X[:, 0], X[:, 1], s=120, color=labels_cmap(y))
    

def show_descision_boundary(clf, limits, binary=False, X=None, y=None, n_lines=10, show_lines=False,
                           figsize=(5, 5), ax=None):
    if limits is None:
        if X is not None:
            xs = [X[:, 0].min() - .3, X[:, 0].max() + .3]
            ys = [X[:, 1].min() - .3, X[:, 1].max() + .3]
        else:
            xs = [-1, 1]
            ys = [-1, 1]
    else:
        xs, ys = limits
    
    x_min, x_max = xs
    y_min, y_max = ys
    
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
                         np.arange(y_min, y_max, 0.01))
    
    if ax is None:
        fig = plt.figure(figsize=figsize)
        ax = fig.add_subplot(1, 1, 1)
    
    if binary:
        Z = clf.predict(np.c_[xx.ravel(), xx.ravel()])
        Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
        norm = Normalize(vmin=0.,vmax=1.)
    else:
        Z = clf(np.c_[xx.ravel(), xx.ravel()])
        Z = clf(np.c_[xx.ravel(), yy.ravel()])
        #if clf.prob_output:
        #    norm = Normalize(vmin=0.,vmax=1.)
        #else:
        norm = Normalize(vmin=-10.,vmax=10., clip=True)
        Z = Z.numpy() 
    
    Z = Z.reshape(xx.shape)
    Z = Z.astype(np.float32)
    
    ax.contourf(xx, yy, Z, n_lines, alpha=0.4, cmap=main_cmap, norm=norm)
    if show_lines:
        cp = ax.contour(xx, yy, Z, n_lines)
        ax.clabel(cp, inline=True, 
              fontsize=10, colors="green")
    
    if y is not None:
        X = np.array(X)
        y = np.array(y)
        ax.scatter(X[:, 0], X[:, 1], s=120, color=labels_cmap(y),
                   zorder=4)
        

def eval_model(model, X, y):
    accuracy = model.evaluate(X, y)[1]
    if accuracy == 1.0:
        print("Perfect!")
    elif  accuracy > 0.9:
        print("Well done! Can you make 100%?")
    else:
        print("Don't give up!")
    return accuracy

# %% [markdown]
# **1a**. Начнем с классической задачи -- XOR.

# %%
X = np.random.rand(200, 2) - 0.5
y = ((X[:, 0] < 0) ^ (X[:, 1] < 0))
X = X*2
show_data(X, y)

# %%
model = tf.keras.Sequential()
# <YOUR CODE STARTS HERE>
# 1. добавьте скрытые слои в модель (в первом из них не забудьте про input_shape)
#    ~3 скрытых слоев достаточно
# 2. добавьте выходной слой он должен быть без активации
# 3. определите оптимизатор 
# 4. определите лосс (не забудьте указать from_logits=True!!) 







# <YOUR CODE ENDS HERE>

model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"]) 
history = model.fit(X, y, epochs=200, verbose=1, batch_size=64, shuffle=True)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 7ms/step - loss: 0.6999 - accuracy: 0.5000
# Epoch 2/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6962 - accuracy: 0.5000
# Epoch 3/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5000
# Epoch 4/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6899 - accuracy: 0.5000
# Epoch 5/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6872 - accuracy: 0.5000
# Epoch 6/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6842 - accuracy: 0.5000
# Epoch 7/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6818 - accuracy: 0.5000
# Epoch 8/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6795 - accuracy: 0.5000
# Epoch 9/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.5000
# Epoch 10/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6761 - accuracy: 0.5000
# Epoch 11/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6743 - accuracy: 0.5000
# Epoch 12/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6729 - accuracy: 0.5000
# Epoch 13/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6714 - accuracy: 0.5000
# Epoch 14/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6697 - accuracy: 0.5000
# Epoch 15/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6679 - accuracy: 0.5000
# Epoch 16/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6661 - accuracy: 0.5000
# Epoch 17/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6643 - accuracy: 0.5000
# Epoch 18/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6623 - accuracy: 0.5000
# Epoch 19/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6604 - accuracy: 0.5000
# Epoch 20/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6583 - accuracy: 0.5000
# Epoch 21/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6562 - accuracy: 0.5000
# Epoch 22/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6541 - accuracy: 0.5000
# Epoch 23/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6519 - accuracy: 0.5000
# Epoch 24/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6495 - accuracy: 0.5000
# Epoch 25/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6472 - accuracy: 0.5000
# Epoch 26/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6446 - accuracy: 0.5000
# Epoch 27/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6420 - accuracy: 0.5000
# Epoch 28/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6393 - accuracy: 0.5000
# Epoch 29/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6365 - accuracy: 0.5000
# Epoch 30/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6336 - accuracy: 0.5000
# Epoch 31/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6306 - accuracy: 0.5000
# Epoch 32/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6274 - accuracy: 0.5000
# Epoch 33/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6243 - accuracy: 0.5000
# Epoch 34/200
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6209 - accuracy: 0.5000
# Epoch 35/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6173 - accuracy: 0.5000
# Epoch 36/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6138 - accuracy: 0.5000
# Epoch 37/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6099 - accuracy: 0.5000
# Epoch 38/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6061 - accuracy: 0.5000
# Epoch 39/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6021 - accuracy: 0.5000
# Epoch 40/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5980 - accuracy: 0.5000
# Epoch 41/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5937 - accuracy: 0.5000
# Epoch 42/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5891 - accuracy: 0.5000
# Epoch 43/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5847 - accuracy: 0.5000
# Epoch 44/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5799 - accuracy: 0.5000
# Epoch 45/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5751 - accuracy: 0.5000
# Epoch 46/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5701 - accuracy: 0.5000
# Epoch 47/200
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5651 - accuracy: 0.5000
# Epoch 48/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5599 - accuracy: 0.5000
# Epoch 49/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5547 - accuracy: 0.5100
# Epoch 50/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5493 - accuracy: 0.5700
# Epoch 51/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5441 - accuracy: 0.6000
# Epoch 52/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5383 - accuracy: 0.6200
# Epoch 53/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5324 - accuracy: 0.6400
# Epoch 54/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5267 - accuracy: 0.6700
# Epoch 55/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5206 - accuracy: 0.6900
# Epoch 56/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5146 - accuracy: 0.7000
# Epoch 57/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5088 - accuracy: 0.7100
# Epoch 58/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5024 - accuracy: 0.7400
# Epoch 59/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4962 - accuracy: 0.7600
# Epoch 60/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4898 - accuracy: 0.7700
# Epoch 61/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4830 - accuracy: 0.7900
# Epoch 62/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4761 - accuracy: 0.7900
# Epoch 63/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4697 - accuracy: 0.8000
# Epoch 64/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4628 - accuracy: 0.8200
# Epoch 65/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4559 - accuracy: 0.8300
# Epoch 66/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4489 - accuracy: 0.8300
# Epoch 67/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4426 - accuracy: 0.8600
# Epoch 68/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4355 - accuracy: 0.8500
# Epoch 69/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4290 - accuracy: 0.8500
# Epoch 70/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4221 - accuracy: 0.8800
# Epoch 71/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4152 - accuracy: 0.8700
# Epoch 72/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4081 - accuracy: 0.8700
# Epoch 73/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4018 - accuracy: 0.8700
# Epoch 74/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3947 - accuracy: 0.8700
# Epoch 75/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3881 - accuracy: 0.8700
# Epoch 76/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3811 - accuracy: 0.8700
# Epoch 77/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3747 - accuracy: 0.8700
# Epoch 78/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3679 - accuracy: 0.8700
# Epoch 79/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3614 - accuracy: 0.8700
# Epoch 80/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3551 - accuracy: 0.8700
# Epoch 81/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3490 - accuracy: 0.8800
# Epoch 82/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3431 - accuracy: 0.8800
# Epoch 83/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3376 - accuracy: 0.8800
# Epoch 84/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3314 - accuracy: 0.8800
# Epoch 85/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3258 - accuracy: 0.8700
# Epoch 86/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3206 - accuracy: 0.8800
# Epoch 87/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3155 - accuracy: 0.8800
# Epoch 88/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3106 - accuracy: 0.8800
# Epoch 89/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3056 - accuracy: 0.8800
# Epoch 90/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3005 - accuracy: 0.8800
# Epoch 91/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2962 - accuracy: 0.8800
# Epoch 92/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2917 - accuracy: 0.8900
# Epoch 93/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2874 - accuracy: 0.8900
# Epoch 94/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2835 - accuracy: 0.8900
# Epoch 95/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2792 - accuracy: 0.9000
# Epoch 96/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2754 - accuracy: 0.9000
# Epoch 97/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2715 - accuracy: 0.8900
# Epoch 98/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2681 - accuracy: 0.8900
# Epoch 99/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2646 - accuracy: 0.8900
# Epoch 100/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2613 - accuracy: 0.8900
# Epoch 101/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2579 - accuracy: 0.8900
# Epoch 102/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2547 - accuracy: 0.8900
# Epoch 103/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2518 - accuracy: 0.8900
# Epoch 104/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2486 - accuracy: 0.8900
# Epoch 105/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2457 - accuracy: 0.8900
# Epoch 106/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2430 - accuracy: 0.8800
# Epoch 107/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2400 - accuracy: 0.8800
# Epoch 108/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2375 - accuracy: 0.8800
# Epoch 109/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2352 - accuracy: 0.8800
# Epoch 110/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2326 - accuracy: 0.8800
# Epoch 111/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2301 - accuracy: 0.8800
# Epoch 112/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2279 - accuracy: 0.8800
# Epoch 113/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2257 - accuracy: 0.8800
# Epoch 114/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2228 - accuracy: 0.8900
# Epoch 115/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2206 - accuracy: 0.8900
# Epoch 116/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2184 - accuracy: 0.8900
# Epoch 117/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2160 - accuracy: 0.8900
# Epoch 118/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2139 - accuracy: 0.8900
# Epoch 119/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2116 - accuracy: 0.8900
# Epoch 120/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2094 - accuracy: 0.8900
# Epoch 121/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2073 - accuracy: 0.9000
# Epoch 122/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2049 - accuracy: 0.9000
# Epoch 123/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2029 - accuracy: 0.9000
# Epoch 124/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2008 - accuracy: 0.9000
# Epoch 125/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1986 - accuracy: 0.9000
# Epoch 126/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1968 - accuracy: 0.9000
# Epoch 127/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1945 - accuracy: 0.9000
# Epoch 128/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1925 - accuracy: 0.9000
# Epoch 129/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1903 - accuracy: 0.9000
# Epoch 130/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1885 - accuracy: 0.9000
# Epoch 131/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1865 - accuracy: 0.9000
# Epoch 132/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1847 - accuracy: 0.9000
# Epoch 133/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1827 - accuracy: 0.9000
# Epoch 134/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1810 - accuracy: 0.9000
# Epoch 135/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1794 - accuracy: 0.9000
# Epoch 136/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1774 - accuracy: 0.9000
# Epoch 137/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1759 - accuracy: 0.9000
# Epoch 138/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.1743 - accuracy: 0.9000
# Epoch 139/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1724 - accuracy: 0.9000
# Epoch 140/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1706 - accuracy: 0.9000
# Epoch 141/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1690 - accuracy: 0.9100
# Epoch 142/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1672 - accuracy: 0.9100
# Epoch 143/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1656 - accuracy: 0.9100
# Epoch 144/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1641 - accuracy: 0.9100
# Epoch 145/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1623 - accuracy: 0.9100
# Epoch 146/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1608 - accuracy: 0.9100
# Epoch 147/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1593 - accuracy: 0.9100
# Epoch 148/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1578 - accuracy: 0.9100
# Epoch 149/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1563 - accuracy: 0.9100
# Epoch 150/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1546 - accuracy: 0.9100
# Epoch 151/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1532 - accuracy: 0.9100
# Epoch 152/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1517 - accuracy: 0.9100
# Epoch 153/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1502 - accuracy: 0.9100
# Epoch 154/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1489 - accuracy: 0.9200
# Epoch 155/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1473 - accuracy: 0.9200
# Epoch 156/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1461 - accuracy: 0.9200
# Epoch 157/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1452 - accuracy: 0.9200
# Epoch 158/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1434 - accuracy: 0.9200
# Epoch 159/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1421 - accuracy: 0.9200
# Epoch 160/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1408 - accuracy: 0.9200
# Epoch 161/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1395 - accuracy: 0.9300
# Epoch 162/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1387 - accuracy: 0.9200
# Epoch 163/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1369 - accuracy: 0.9200
# Epoch 164/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1351 - accuracy: 0.9300
# Epoch 165/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1345 - accuracy: 0.9400
# Epoch 166/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1328 - accuracy: 0.9300
# Epoch 167/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1323 - accuracy: 0.9300
# Epoch 168/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1311 - accuracy: 0.9300
# Epoch 169/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1297 - accuracy: 0.9300
# Epoch 170/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1284 - accuracy: 0.9300
# Epoch 171/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1269 - accuracy: 0.9300
# Epoch 172/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1260 - accuracy: 0.9400
# Epoch 173/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1243 - accuracy: 0.9400
# Epoch 174/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1234 - accuracy: 0.9400
# Epoch 175/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1223 - accuracy: 0.9400
# Epoch 176/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1216 - accuracy: 0.9400
# Epoch 177/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1202 - accuracy: 0.9400
# Epoch 178/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1191 - accuracy: 0.9400
# Epoch 179/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1180 - accuracy: 0.9500
# Epoch 180/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1165 - accuracy: 0.9500
# Epoch 181/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1155 - accuracy: 0.9500
# Epoch 182/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1143 - accuracy: 0.9500
# Epoch 183/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1133 - accuracy: 0.9500
# Epoch 184/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1125 - accuracy: 0.9500
# Epoch 185/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1113 - accuracy: 0.9500
# Epoch 186/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1102 - accuracy: 0.9500
# Epoch 187/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1090 - accuracy: 0.9500
# Epoch 188/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1079 - accuracy: 0.9500
# Epoch 189/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1070 - accuracy: 0.9500
# Epoch 190/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1058 - accuracy: 0.9500
# Epoch 191/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1048 - accuracy: 0.9500
# Epoch 192/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1038 - accuracy: 0.9500
# Epoch 193/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1029 - accuracy: 0.9500
# Epoch 194/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1021 - accuracy: 0.9500
# Epoch 195/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1008 - accuracy: 0.9500
# Epoch 196/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0999 - accuracy: 0.9500
# Epoch 197/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0990 - accuracy: 0.9500
# Epoch 198/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0983 - accuracy: 0.9500
# Epoch 199/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0972 - accuracy: 0.9500
# Epoch 200/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0961 - accuracy: 0.9500

# %%
limits = [[-0.6, 0.6], [-0.6, 0.6]]
eval_model(model, X, y)
show_descision_boundary(limits=None, clf=model, binary=False,
                                X=X,
                                y=y, 
                                n_lines=50,
                                show_lines=False)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0953 - accuracy: 0.9500
# Well done! Can you make 100%?

# %% [markdown]
# **1b**

# %%
from sklearn.datasets import make_moons

X, y = make_moons(noise=0.04)
show_data(X, y)

# %%
model = tf.keras.Sequential()
# <YOUR CODE STARTS HERE>
# 1. добавьте скрытые слои в модель (в первом из них не забудьте про input_shape)
#    ~3 скрытых слоев достаточно
# 2. добавьте выходной слой он должен быть без активации
# 3. определите оптимизатор 
# 4. определите лосс (не забудьте указать from_logits=True!!) 









# <YOUR CODE ENDS HERE>

model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"]) 
history = model.fit(X, y, epochs=200, verbose=1, batch_size=64, shuffle=True)

# %%
eval_model(model, X, y)
show_descision_boundary(limits=None, clf=model, binary=False,
                                X=X,
                                y=y, 
                                n_lines=50,
                                show_lines=False)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0953 - accuracy: 0.9500
# Well done! Can you make 100%?

# %% [markdown]
# **1c**

# %%
from sklearn.datasets import make_circles

X, y = make_circles(factor=0.5, noise=0.05)
show_data(X, y)

# %%
model = tf.keras.Sequential()
# <YOUR CODE STARTS HERE>
# 1. добавьте скрытые слои в модель (в первом из них не забудьте про input_shape)
#    Постарайтесь сделать количество слоев и нейронов минимальным.
# 2. добавьте выходной слой он должен быть без активации
# 3. определите оптимизатор 
# 4. определите лосс (не забудьте указать from_logits=True!!) 








# <YOUR CODE ENDS HERE>

model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"]) 
history = model.fit(X, y, epochs=200, verbose=1, batch_size=64, shuffle=True)

# %%
accuracy = eval_model(model, X, y)
if model.count_params() < 18 and accuracy == 1.0:
    print("Bonus points!")
else:
    print(f"Model has {model.count_params()} parameters")

show_descision_boundary(limits=None, clf=model, binary=False,
                                X=X,
                                y=y, 
                                n_lines=50,
                                show_lines=False)
